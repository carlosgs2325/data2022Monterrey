# %%
# %matplotlib inline
import pandas as pd

# %%
compras_df=pd.read_csv('data/compras_df_enriched.csv')

# %%
data=compras_df.copy()

# %% [markdown]
# # LLenar los valores faltantes del DF

# %%
for i,column in enumerate(list([str(d) for d in data.dtypes])):
    if column =="object":
        data[data.columns[i]]=data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]]=data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]]=data[data.columns[i]].fillna(data[data.columns[i]].median())

# %% [markdown]
# # Utilizar Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
y=data.pop('IMPORTE')

# %%
X=data.copy()

# %%
X
# Out:
#        CVE BEN  BENEFICIARIO   RFC  FACTURAS  CONTRATO  CONCEPTO  TIPO  \
# 0       116117          2325  2319      3987      5928     12480     1
# 1       123046           449   524      6782      5925     12484     1
# 2       123262           452   408       589      5931     12481     1
# 3       123318          2225  2163     10478      5926     12486     1
# 4       123530          2187  2222      6216      5933     12485     1
# ...        ...           ...   ...       ...       ...       ...   ...
# 17691   203016          2068  2112      7731        73      7992     0
# 17692   203016          2068  2112      7732        73      8000     0
# 17693   203016          2118  2118      3822        73      5119     0
# 17694   203016          2226  2230       260        73      8035     0
# 17695   203016          2286  2294      4239        73      7205     0
#
#            FDO-#OP  FECHA  SHEET  DIA  MES   AÑO  BENEFICIARIO_SALES  \
# 0        1021658.0      0      1   28    1  2022                  13
# 1        1021659.0      0      1   28    1  2022                  39
# 2        1021665.0      0      1   28    1  2022                  36
# 3        1021660.0      0      1   28    1  2022                  24
# 4        1021667.0      0      1   28    1  2022                  38
# ...            ...    ...    ...  ...  ...   ...                 ...
# 17691  330001189.0    213      3   12   12  2022                  23
# 17692  330001207.0    216      3   15   12  2022                  23
# 17693    1109177.0    216      3   15   12  2022                   2
# 17694  330001168.0    209      3    6   12  2022                   1
# 17695  330001209.0    216      3   15   12  2022                  11
#
#        IMPORTE_GASTO_PROMEDIO
# 0               412968.725943
# 1               412968.725943
# 2               412968.725943
# 3               412968.725943
# 4               412968.725943
# ...                       ...
# 17691            36627.152716
# 17692            36627.152716
# 17693            36627.152716
# 17694            36627.152716
# 17695            36627.152716
#
# [17696 rows x 15 columns]

# %% [markdown]
# # Dividir los datos en grupos

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.33, random_state=42)

# %%
clf= RandomForestRegressor(n_estimators=1000, max_depth=4)

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=1000)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, clf.predict(X_test))
# Out:
# 0.1988019229136736

# %% [markdown]
# # Modelo No Supervisado

# %%
import warnings
warnings.filterwarnings("ignore",category=UserWarning, module="sklearn")
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
compras_df_c=compras_df.copy()

# %%
#Como variable adicional, se consideró el número de meses en los que 
#se dieron los contratos.
compras_df_c_grupo=compras_df_c.groupby('BENEFICIARIO').agg({'CONTRATO': lambda x: x.nunique(), 'IMPORTE': 'sum',
                                                            'FACTURAS': lambda x: x.nunique(), 'MES': lambda x: x.nunique()})

# %%
compras_df_cluster=compras_df_c_grupo.reset_index()

# %%
compras_df_cluster
# Out:
#                                           BENEFICIARIO  CONTRATO     IMPORTE  \
# 0                    2814 INMUEBLES S. DE R.L. DE C.V.         1    24896.00
# 1                      A&T IMPORTACIONES, S.A. DE C.V.        18  4483538.44
# 2                              ABAD MORENO MILCA SARAI         1   270001.41
# 3     ABASTECEDORA DE GIMNASIOS HERCULES, S DE R.L. MI         2  1443386.55
# 4                                     ABUNDIS  ALBERTO         2   435386.86
# ...                                                ...       ...         ...
# 2464                  ZENTENO SALAZAR CLAUDIA VICTORIA         1    18315.09
# 2465                       ZEPEDA CARDONA LAURA AMPARO         1     6328.57
# 2466                         ZUL GONZALEZ JOSE ANTONIO         1   118576.67
# 2467                  ZUNIGA HERNANDEZ ADELA ELIZABETH         1    46024.30
# 2468                           ZUÑIGA MARTINEZ ANAYELY         1     6934.77
#
#       FACTURAS  MES
# 0            1    1
# 1           18    6
# 2            1    1
# 3            2    2
# 4           10    7
# ...        ...  ...
# 2464         2    2
# 2465         1    1
# 2466         2    1
# 2467         2    2
# 2468         2    2
#
# [2469 rows x 5 columns]

# %%
compras_df_c_grupo_f=compras_df_c_grupo.reset_index().drop(['BENEFICIARIO'], axis=1)

# %%
normalizado_compras_df=(compras_df_c_grupo_f - compras_df_c_grupo_f.min())/(compras_df_c_grupo_f.max()-compras_df_c_grupo_f.min())

# %%
normalizado_compras_df
# Out:
#       CONTRATO   IMPORTE  FACTURAS       MES
# 0     0.000000  0.000015  0.000000  0.000000
# 1     0.047091  0.002798  0.011177  0.454545
# 2     0.000000  0.000168  0.000000  0.000000
# 3     0.002770  0.000901  0.000657  0.090909
# 4     0.002770  0.000272  0.005917  0.545455
# ...        ...       ...       ...       ...
# 2464  0.000000  0.000011  0.000657  0.090909
# 2465  0.000000  0.000004  0.000000  0.000000
# 2466  0.000000  0.000074  0.000657  0.000000
# 2467  0.000000  0.000029  0.000657  0.090909
# 2468  0.000000  0.000004  0.000657  0.090909
#
# [2469 rows x 4 columns]

# %%
wcss=[]

# %%
for i in range(1,20):
    kmeans=KMeans(n_clusters=i, max_iter=300)
    kmeans.fit(normalizado_compras_df)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,20), wcss)
plt.title('Codo de Jambu')
plt.xlabel('Numero de cluster')
plt.ylabel('WCSS')  #Indica lacantidad de similitud de los individuos
plt.show()

# %%
clustering=KMeans(n_clusters=6, max_iter=300)

# %%
clustering.fit(normalizado_compras_df)
# Out:
# KMeans(n_clusters=6)

# %%
compras_df_cluster['KMeans_Cluster']=clustering.labels_

# %%
compras_df_cluster['KMeans_Cluster'].value_counts()
# Out:
# KMeans_Cluster
# 2    1622
# 0     475
# 4     163
# 1      96
# 5      95
# 3      18
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca_compras=pca.fit_transform(normalizado_compras_df)

# %%
pca_compras_df=pd.DataFrame(data=pca_compras, columns=['componente_1', 'componente_2'])

# %%
pca_nombres_beneficia=pd.concat([pca_compras_df, compras_df_cluster['KMeans_Cluster']], axis=1)

# %%
pca_nombres_beneficia
# Out:
#       componente_1  componente_2  KMeans_Cluster
# 0        -0.104848      0.001859               2
# 1         0.351954      0.009234               4
# 2        -0.104845      0.001856               2
# 3        -0.014074     -0.003436               0
# 4         0.438691     -0.042162               1
# ...            ...           ...             ...
# 2464     -0.014311     -0.006020               0
# 2465     -0.104849      0.001859               2
# 2466     -0.104816      0.002077               2
# 2467     -0.014311     -0.006020               0
# 2468     -0.014311     -0.006020               0
#
# [2469 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))

# %%
scatter=plt.scatter(pca_nombres_beneficia['componente_1'],
                   pca_nombres_beneficia['componente_2'],
                   c=pca_nombres_beneficia['KMeans_Cluster'],
                   cmap='viridis',
                   s=100,
                   alpha=0.7)

#Añadir el titulo y etiquetas
plt.title('Clusters formados mediante KMeans y PCA')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
legend1=plt.legend(*scatter.legend_elements(), title='Clusters')
plt.gca().add_artist(legend1)
plt.grid()
plt.show()
