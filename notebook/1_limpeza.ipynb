# %%
# importat la libreria de pandas
import pandas as pd

# %%
#importar la libreria del sistema operativo
import os

# %%
# !dir
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 5866-EF29
#
#  Directorio de C:\Users\CarlosRGS\Tarea 2 IA CdD\notebook
#
# 16/10/2024  12:02    <DIR>          .
# 16/10/2024  12:06    <DIR>          ..
# 15/10/2024  10:13    <DIR>          .ipynb_checkpoints
# 16/10/2024  10:44            68.055 1_limpeza.ipynb
# 15/10/2024  10:13           407.299 2_analisis.ipynb
# 16/10/2024  12:02            26.816 3_enriquecimiento.ipynb
# 16/10/2024  11:53           142.796 4_modelado.ipynb
# 16/10/2024  10:40    <DIR>          data
#                4 archivos        644.966 bytes
#                4 dirs  129.216.167.936 bytes libres

# %%
os.chdir('C:/Users/CarlosRGS/Tarea 2 IA CdD')   #Cambiar la Dirección para cada PC

# %%
df_contratistas_ENE=pd.read_excel('01_ENERO_2022.xlsx',
                                  sheet_name='OB.PUBLICA-GTS VARIOS (FDO ESP)', skiprows=5)
df_contratistas_ENE['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_ENE = pd.read_excel('01_ENERO_2022.xlsx', sheet_name='GTS VARIOS', skiprows=5)
df_gastos_varios_ENE['SHEET'] = 'GASTOS VARIOS'
df_gastos_repr_ENE = pd.read_excel('01_ENERO_2022.xlsx', sheet_name='GTS REPRESENT', skiprows=5)
df_gastos_repr_ENE['SHEET'] = 'REPRESENTACION'
df_personales_ENE = pd.read_excel('01_ENERO_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_ENE['SHEET'] = 'PERSONALES'

# %%
df_compras_ENE=pd.concat([df_contratistas_ENE,df_gastos_varios_ENE,df_gastos_repr_ENE,df_personales_ENE])

# %%
df_compras_ENE=df_compras_ENE.rename(columns={'NUM BEN': 'CVE BEN', 'FACTURA': 'FACTURAS'})
df_compras_ENE.head(2)
# Out:
#         CVE BEN                      BENEFICIARIO           RFC  \
# 0        116117  URBANIZACIONES AGV, S.A. DE C.V.  UAG010828F33
# 1  Total 116117                               NaN           NaN
#
#         FACTURAS      CONTRATO  \
# 0  2157-185004-6  SIS-005-2022
# 1            NaN           NaN
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  RP 30% ANT. SIS-RP-02/21-CP ADEC. EN INTERS.VI...   TR  1021658.0
# 1                                                NaN  NaN        NaN
#
#        FECHA     IMPORTE         SHEET
# 0 2022-01-28  2213909.61  CONTRATISTAS
# 1        NaT  2213909.61  CONTRATISTAS

# %%
df_contratistas_FEB=pd.read_excel('02_FEBRERO_2022.xlsx',
                                  sheet_name='OB.PUBLICA-GTS VARIOS (FDO ESP)', skiprows=5)
df_contratistas_FEB['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_FEB = pd.read_excel('02_FEBRERO_2022.xlsx', sheet_name='GTS VARIOS', skiprows=5)
df_gastos_varios_FEB['SHEET'] = 'GASTOS VARIOS'
df_servicios_FEB = pd.read_excel('02_FEBRERO_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_FEB['SHEET'] = 'SERVICIOS'
df_personales_FEB = pd.read_excel('02_FEBRERO_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_FEB['SHEET'] = 'PERSONALES'

# %%
df_compras_FEB=pd.concat([df_contratistas_FEB,df_gastos_varios_FEB,df_servicios_FEB,df_personales_FEB])

# %%
df_compras_FEB=df_compras_FEB.rename(columns={'FACTURA': 'FACTURAS'})
df_compras_FEB.head(2)
# Out:
#         CVE BEN                  BENEFICIARIO           RFC         FACTURAS  \
# 0        115978  MAXIMO ESPACIO, S.A. DE C.V.  MES0609061B2  10265-183011-54
# 1  Total 115978                           NaN           NaN              NaN
#
#                     CONTRATO  \
# 0  SFA-DGA-DASG/CC/0003/2022
# 1                        NaN
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  SUMINISTRO DE INSUMOS PARA LA ADECUACION DEL C...   TR  334000004.0
# 1                                                NaN  NaN          NaN
#
#        FECHA    IMPORTE         SHEET
# 0 2022-02-18  903580.84  CONTRATISTAS
# 1        NaT  903580.84  CONTRATISTAS

# %%
df_contratistas_MAR=pd.read_excel('03_MARZO_2022.xlsx',
                                  sheet_name='OB.PUBLICA-GTS VARIOS (FDO ESP)', skiprows=5)
df_contratistas_MAR['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_MAR = pd.read_excel('03_MARZO_2022.xlsx', sheet_name='GTOS VARIOS', skiprows=5)
df_gastos_varios_MAR['SHEET'] = 'GASTOS VARIOS'
df_servicios_MAR= pd.read_excel('03_MARZO_2022.xlsx', sheet_name='SERV.PROF.', skiprows=5)
df_servicios_MAR['SHEET'] = 'SERVICIOS'
df_comunicacion_MAR= pd.read_excel('03_MARZO_2022.xlsx', sheet_name='COMUNICACION', skiprows=5)
df_comunicacion_MAR['SHEET'] = 'COMUNICACION'
df_viaje_MAR= pd.read_excel('03_MARZO_2022.xlsx', sheet_name='GASTOS DE VIAJE', skiprows=5)
df_viaje_MAR['SHEET'] = 'VIAJE'
df_personales_MAR= pd.read_excel('03_MARZO_2022.xlsx', sheet_name='SERV PERS.', skiprows=5)
df_personales_MAR['SHEET'] = 'PERSONALES'

# %%
df_compras_MAR=pd.concat([df_contratistas_MAR,df_gastos_varios_MAR,df_servicios_MAR, df_comunicacion_MAR, 
                         df_viaje_MAR,df_personales_MAR])

# %%
df_compras_MAR=df_compras_MAR.rename(columns={'FECHA\nPAGO': 'FECHA', 'FACTURA': 'FACTURAS'})
df_compras_MAR.head(2)
# Out:
#   CVE BEN       BENEFICIARIO           RFC                 FACTURAS  \
# 0  110036  SEMEX,S.A.DE C.V.  SEM680801193        40050-158003-3749
# 1  110036  SEMEX,S.A.DE C.V.  SEM680801193  FACSMX40594-158003-4457
#
#        CONTRATO                                           CONCEPTO TIPO  \
# 0  SIV-004-2020  EST. 13 PARA EL SUMINISTRO Y APLICACION DE PIN...   TR
# 1  SIV-006-2020  SUMINISTRO DE MATERIALES PARA SEÑALAMIENTOS VI...   TR
#
#        FDO-#OP      FECHA     IMPORTE         SHEET
# 0  319000832.0 2022-03-04  2832757.10  CONTRATISTAS
# 1  319000832.0 2022-03-04   366163.05  CONTRATISTAS

# %%
df_contratistas_ABR=pd.read_excel('04_ABRIL_2022.xlsx',
                                  sheet_name='OB.PUBLICA-GTS VARIOS (FDO ESP)', skiprows=5)
df_contratistas_ABR['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_ABR = pd.read_excel('04_ABRIL_2022.xlsx', sheet_name='GTS VARIOS', skiprows=5)
df_gastos_varios_ABR['SHEET'] = 'GASTOS VARIOS'
df_servicios_ABR= pd.read_excel('04_ABRIL_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_ABR['SHEET'] = 'SERVICIOS'
df_comunicacion_ABR= pd.read_excel('04_ABRIL_2022.xlsx', sheet_name='COMUNIC', skiprows=5)
df_comunicacion_ABR['SHEET'] = 'COMUNICACION'
df_represent_ABR= pd.read_excel('04_ABRIL_2022.xlsx', sheet_name='GTS REPRESENT', skiprows=5)
df_represent_ABR['SHEET'] = 'REPRESENTACION'
df_personales_ABR= pd.read_excel('04_ABRIL_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_ABR['SHEET'] = 'PERSONALES'

# %%
df_compras_ABR=pd.concat([df_contratistas_ABR,df_gastos_varios_ABR,df_servicios_ABR, df_comunicacion_ABR, 
                         df_represent_ABR,df_personales_ABR])

# %%
df_compras_ABR=df_compras_ABR.rename(columns={'FACTURA': 'FACTURAS'})
df_compras_ABR.head(2)
# Out:
#   CVE BEN       BENEFICIARIO           RFC                FACTURAS CONTRATO  \
# 0  110036  SEMEX,S.A.DE C.V.  SEM680801193  FACSMX42334-183011-161  OC 7513
# 1  110036  SEMEX,S.A.DE C.V.  SEM680801193  FACSMX42335-183011-162  OC 7514
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  SUMINISTRO DE MATERIALES PARA SEÑALAMIENTOS VI...   TR  327000050.0
# 1  SUMINISTRO DE MATERIALES PARA SEÑALAMIENTOS VI...   TR  327000050.0
#
#        FECHA    IMPORTE         SHEET
# 0 2022-04-01  654915.23  CONTRATISTAS
# 1 2022-04-01  178327.15  CONTRATISTAS

# %%
df_contratistas_MAY=pd.read_excel('05_MAYO_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_MAY['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_MAY = pd.read_excel('05_MAYO_2022.xlsx', sheet_name='GTOS VARIOS', skiprows=5)
df_gastos_varios_MAY['SHEET'] = 'GASTOS VARIOS'
df_servicios_MAY= pd.read_excel('05_MAYO_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_MAY['SHEET'] = 'SERVICIOS'
df_comunicacion_MAY= pd.read_excel('05_MAYO_2022.xlsx', sheet_name='COMUNICACION', skiprows=5)
df_comunicacion_MAY['SHEET'] = 'COMUNICACION'
df_repre_MAY= pd.read_excel('05_MAYO_2022.xlsx', sheet_name='GTS DE REPRE', skiprows=5)
df_repre_MAY['SHEET'] = 'REPRESENTACION'
df_personales_MAY= pd.read_excel('05_MAYO_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_MAY['SHEET'] = 'PERSONALES'

# %%
df_compras_MAY=pd.concat([df_contratistas_MAY,df_gastos_varios_MAY,df_servicios_MAY, df_comunicacion_MAY, 
                         df_repre_MAY,df_personales_MAY])

# %%
df_compras_MAY=df_compras_MAY.rename(columns={'FECHA\nPAGO': 'FECHA', 'FACTURA': 'FACTURAS'})
df_compras_MAY.head(2)
# Out:
#         CVE BEN       BENEFICIARIO           RFC                   FACTURAS  \
# 0        110036  SEMEX,S.A.DE C.V.  SEM680801193  FACSMX00043525-185004-545
# 1  Total 110036                NaN           NaN                        NaN
#
#        CONTRATO                                           CONCEPTO TIPO  \
# 0  SIS-007-2022  RP-2022 EST. 1  SIS-RP-01/21-AD SEÑALIZACION H...   TR
# 1           NaN                                                NaN  NaN
#
#      FDO-#OP      FECHA    IMPORTE         SHEET
# 0  1022604.0 2022-05-27  375157.46  CONTRATISTAS
# 1        NaN        NaT  375157.46  CONTRATISTAS

# %%
df_contratistas_JUN=pd.read_excel('06_JUNIO_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_JUN['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_JUN = pd.read_excel('06_JUNIO_2022.xlsx', sheet_name='GASTOS VARIOS', skiprows=5)
df_gastos_varios_JUN['SHEET'] = 'GASTOS VARIOS'
df_servicios_JUN= pd.read_excel('06_JUNIO_2022.xlsx', sheet_name='SERV PROV', skiprows=5)
df_servicios_JUN['SHEET'] = 'SERVICIOS'
df_comunicacion_JUN= pd.read_excel('06_JUNIO_2022.xlsx', sheet_name='COMUNIC', skiprows=5)
df_comunicacion_JUN['SHEET'] = 'COMUNICACION'
df_repre_JUN= pd.read_excel('06_JUNIO_2022.xlsx', sheet_name='GTOS REPRE', skiprows=5)
df_repre_JUN['SHEET'] = 'REPRESENTACION'
df_personales_JUN= pd.read_excel('06_JUNIO_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_JUN['SHEET'] = 'PERSONALES'

# %%
df_compras_JUN=pd.concat([df_contratistas_JUN,df_gastos_varios_JUN,df_servicios_JUN, df_comunicacion_JUN, 
                         df_repre_JUN,df_personales_JUN])

# %%
df_compras_JUN.head(2)
# Out:
#         CVE BEN                                      BENEFICIARIO  \
# 0        112100  FUMIGACIONES TECNICAS Y JARDINERIA, S.A. DE C.V.
# 1  Total 112100                                               NaN
#
#             RFC           FACTURAS      CONTRATO  \
# 0  FTJ861224HG1  A5102-183011-1945  SSP-295-2022
# 1           NaN                NaN           NaN
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  MANTENIMIENTO DE AREAS VERDES ZONA NORTE, ESTI...   TR  330000249.0
# 1                                                NaN  NaN          NaN
#
#        FECHA     IMPORTE         SHEET
# 0 2022-06-10  1175710.17  CONTRATISTAS
# 1        NaT  1175710.17  CONTRATISTAS

# %%
df_contratistas_JUL=pd.read_excel('07_JULIO_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_JUL['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_JUL = pd.read_excel('07_JULIO_2022.xlsx', sheet_name='GTOS VARIOS', skiprows=5)
df_gastos_varios_JUL['SHEET'] = 'GASTOS VARIOS'
df_servicios_JUL= pd.read_excel('07_JULIO_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_JUL['SHEET'] = 'SERVICIOS'
df_comunicacion_JUL= pd.read_excel('07_JULIO_2022.xlsx', sheet_name='COMUNIC', skiprows=5)
df_comunicacion_JUL['SHEET'] = 'COMUNICACION'
df_repre_JUL= pd.read_excel('07_JULIO_2022.xlsx', sheet_name='GTS REPRESENT', skiprows=5)
df_repre_JUL['SHEET'] = 'REPRESENTACION'
df_personales_JUL= pd.read_excel('07_JULIO_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_JUL['SHEET'] = 'PERSONALES'

# %%
df_compras_JUL=pd.concat([df_contratistas_JUL,df_gastos_varios_JUL,df_servicios_JUL, df_comunicacion_JUL, 
                         df_repre_JUL,df_personales_JUL])

# %%
df_compras_JUL.head(2)
# Out:
#   CVE BEN                                      BENEFICIARIO           RFC  \
# 0  112100  FUMIGACIONES TECNICAS Y JARDINERIA, S.A. DE C.V.  FTJ861224HG1
# 1  112100  FUMIGACIONES TECNICAS Y JARDINERIA, S.A. DE C.V.  FTJ861224HG1
#
#             FACTURAS      CONTRATO  \
# 0  A5147-183011-2795  SSP-295-2022
# 1  A5255-183011-3410  SSP-295-2022
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  MANTENIMIENTO DE AREAS VERDES ZONA NORTE, ESTI...   TR  330000366.0
# 1  MANTENIMIENTO DE AREAS VERDES ZONA NORTE, ESTI...   TR  330000443.0
#
#        FECHA     IMPORTE         SHEET
# 0 2022-07-08  1175710.17  CONTRATISTAS
# 1 2022-07-29  1175710.17  CONTRATISTAS

# %%
df_contratistas_AGO=pd.read_excel('08_AGOSTO_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_AGO['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_AGO = pd.read_excel('08_AGOSTO_2022.xlsx', sheet_name='GTOS VARIOS', skiprows=5)
df_gastos_varios_AGO['SHEET'] = 'GASTOS VARIOS'
df_servicios_AGO= pd.read_excel('08_AGOSTO_2022.xlsx', sheet_name='SERV PROF', skiprows=6)
df_servicios_AGO['SHEET'] = 'SERVICIOS'
df_comunicacion_AGO= pd.read_excel('08_AGOSTO_2022.xlsx', sheet_name='COMUNIC', skiprows=5)
df_comunicacion_AGO['SHEET'] = 'COMUNICACION'
df_repre_AGO= pd.read_excel('08_AGOSTO_2022.xlsx', sheet_name='GTS REPRE', skiprows=5)
df_repre_AGO['SHEET'] = 'REPRESENTACION'
df_personales_AGO= pd.read_excel('08_AGOSTO_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_AGO['SHEET'] = 'PERSONALES'

# %%
df_compras_AGO=pd.concat([df_contratistas_AGO,df_gastos_varios_AGO,df_servicios_AGO, df_comunicacion_AGO, 
                         df_repre_AGO,df_personales_AGO])

# %%
df_compras_AGO.head(2)
# Out:
#         CVE BEN       BENEFICIARIO           RFC         FACTURAS  \
# 0        110036  SEMEX,S.A.DE C.V.  SEM680801193  400-183011-3750
# 1  Total 110036                NaN           NaN              NaN
#
#        CONTRATO                                           CONCEPTO TIPO  \
# 0  SDU-018-2022  SUMINISTRO DE MATERIALES PARA SEÑALAMIENTOS VI...   TR
# 1           NaN                                                NaN  NaN
#
#        FDO-#OP      FECHA     IMPORTE         SHEET
# 0  330000506.0 2022-08-26  1862659.01  CONTRATISTAS
# 1          NaN        NaT  1862659.01  CONTRATISTAS

# %%
df_contratistas_SEP=pd.read_excel('09_SEPTIEMBRE_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_SEP['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_SEP = pd.read_excel('09_SEPTIEMBRE_2022.xlsx', sheet_name='GTOS VARIOS', skiprows=5)
df_gastos_varios_SEP['SHEET'] = 'GASTOS VARIOS'
df_servicios_SEP= pd.read_excel('09_SEPTIEMBRE_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_SEP['SHEET'] = 'SERVICIOS'
df_comunicacion_SEP= pd.read_excel('09_SEPTIEMBRE_2022.xlsx', sheet_name='COMUNICACION', skiprows=5)
df_comunicacion_SEP['SHEET'] = 'COMUNICACION'
df_repre_SEP= pd.read_excel('09_SEPTIEMBRE_2022.xlsx', sheet_name='GTS REPRESENT', skiprows=5)
df_repre_SEP['SHEET'] = 'REPRESENTACION'
df_personales_SEP= pd.read_excel('09_SEPTIEMBRE_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_SEP['SHEET'] = 'PERSONALES'

# %%
df_compras_SEP=pd.concat([df_contratistas_SEP,df_gastos_varios_SEP,df_servicios_SEP, df_comunicacion_SEP, 
                         df_repre_SEP,df_personales_SEP])

# %%
df_compras_SEP.head(2)
# Out:
#   CVE BEN                        BENEFICIARIO           RFC  \
# 0  112106  SEDIESEL REFACCIONES, S.A. DE C.V.  SRE920615K36
# 1  112106  SEDIESEL REFACCIONES, S.A. DE C.V.  SRE920615K36
#
#             FACTURAS      CONTRATO  \
# 0  A7247-183012-2350  OT. 20221628
# 1  A7352-183012-2461  OT. 20221626
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  REEMPLAZO E INSTALACION DE FILTRO DE AIRE, FIL...   TR  330000529.0
# 1  REEMP E INSTAL DE FILTRO DE AIRE,FILTRO DE COM...   TR  330000529.0
#
#        FECHA   IMPORTE         SHEET
# 0 2022-09-02  134119.2  CONTRATISTAS
# 1 2022-09-02  113838.0  CONTRATISTAS

# %%
df_contratistas_OCT=pd.read_excel('10_OCTUBRE_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_OCT['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_OCT = pd.read_excel('10_OCTUBRE_2022.xlsx', sheet_name='GTS VARIOS', skiprows=5)
df_gastos_varios_OCT['SHEET'] = 'GASTOS VARIOS'
df_servicios_OCT= pd.read_excel('10_OCTUBRE_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_OCT['SHEET'] = 'SERVICIOS'
df_comunicacion_OCT= pd.read_excel('10_OCTUBRE_2022.xlsx', sheet_name='COMUNICACION', skiprows=5)
df_comunicacion_OCT['SHEET'] = 'COMUNICACION'
df_repre_OCT= pd.read_excel('10_OCTUBRE_2022.xlsx', sheet_name='GTS REPRESENT', skiprows=5)
df_repre_OCT['SHEET'] = 'REPRESENTACION'
df_personales_OCT= pd.read_excel('10_OCTUBRE_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_OCT['SHEET'] = 'PERSONALES'

# %%
df_compras_OCT=pd.concat([df_contratistas_OCT,df_gastos_varios_OCT,df_servicios_OCT, df_comunicacion_OCT, 
                         df_repre_OCT,df_personales_OCT])

# %%
df_compras_OCT=df_compras_OCT.rename(columns={'C B': 'CVE BEN', 'FACT': 'FACTURAS', 'FDO - #OP': 'FDO-#OP'})
df_compras_OCT.head(2)
# Out:
#   CVE BEN       BENEFICIARIO           RFC           FACTURAS      CONTRATO  \
# 0  110036  SEMEX,S.A.DE C.V.  SEM680801193    405-183011-4584  SDU-018-2022
# 1  110036  SEMEX,S.A.DE C.V.  SEM680801193  44455-183011-4508  SDU-019-2022
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  SUMINISTRO DE MATERIALES PARA SEÑALAMIENTOS VI...   TR  330000614.0
# 1  ESTIMACION 2 PARA EL SUMINISTRO Y APLICACION D...   TR  330000614.0
#
#        FECHA     IMPORTE         SHEET
# 0 2022-10-07   439001.30  CONTRATISTAS
# 1 2022-10-07  4265544.34  CONTRATISTAS

# %%
df_contratistas_NOV=pd.read_excel('11_NOVIEMBRE_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_NOV['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_NOV = pd.read_excel('11_NOVIEMBRE_2022.xlsx', sheet_name='GTS VARIOS', skiprows=5)
df_gastos_varios_NOV['SHEET'] = 'GASTOS VARIOS'
df_servicios_NOV= pd.read_excel('11_NOVIEMBRE_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_NOV['SHEET'] = 'SERVICIOS'
df_comunicacion_NOV= pd.read_excel('11_NOVIEMBRE_2022.xlsx', sheet_name='COMUNIC', skiprows=5)
df_comunicacion_NOV['SHEET'] = 'COMUNICACION'
df_repre_NOV= pd.read_excel('11_NOVIEMBRE_2022.xlsx', sheet_name='GTS REPRE', skiprows=5)
df_repre_NOV['SHEET'] = 'REPRESENTACION'
df_personales_NOV= pd.read_excel('11_NOVIEMBRE_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_NOV['SHEET'] = 'PERSONALES'

# %%
df_compras_NOV=pd.concat([df_contratistas_NOV,df_gastos_varios_NOV,df_servicios_NOV, df_comunicacion_NOV, 
                         df_repre_NOV,df_personales_NOV])

# %%
df_compras_NOV=df_compras_NOV.rename(columns={'C B': 'CVE BEN', 'FDO - #OP': 'FDO-#OP'})
df_compras_NOV.head(2)
# Out:
#   CVE BEN       BENEFICIARIO           RFC           FACTURAS      CONTRATO  \
# 0  110036  SEMEX,S.A.DE C.V.  SEM680801193  44783-183011-5088  SDU-019-2022
# 1  110036  SEMEX,S.A.DE C.V.  SEM680801193    408-185004-1651  SIS-159-2022
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  ESTIMACION 3 PARA EL SUMINISTRO Y APLICACION D...   TR  330000719.0
# 1  RP-2022 30% ANT. SIS-RP-77/22-CP SEÑALAMIENTO ...   TR    1024694.0
#
#        FECHA     IMPORTE         SHEET
# 0 2022-11-04  4111004.43  CONTRATISTAS
# 1 2022-11-18  7623769.45  CONTRATISTAS

# %%
df_contratistas_DIC=pd.read_excel('12_DICIEMBRE_2022.xlsx',
                                  sheet_name='OBRA PUBLICA Y GV FDOS. ESP', skiprows=5)
df_contratistas_DIC['SHEET'] = 'CONTRATISTAS'
df_gastos_varios_DIC = pd.read_excel('12_DICIEMBRE_2022.xlsx', sheet_name='GTS VARIOS', skiprows=5)
df_gastos_varios_DIC['SHEET'] = 'GASTOS VARIOS'
df_servicios_DIC= pd.read_excel('12_DICIEMBRE_2022.xlsx', sheet_name='SERV PROF', skiprows=5)
df_servicios_DIC['SHEET'] = 'SERVICIOS'
df_comunicacion_DIC= pd.read_excel('12_DICIEMBRE_2022.xlsx', sheet_name='COMUNIC', skiprows=5)
df_comunicacion_DIC['SHEET'] = 'COMUNICACION'
df_repre_DIC= pd.read_excel('12_DICIEMBRE_2022.xlsx', sheet_name='GTS REPRE', skiprows=5)
df_repre_DIC['SHEET'] = 'REPRESENTACION'
df_personales_DIC= pd.read_excel('12_DICIEMBRE_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales_DIC['SHEET'] = 'PERSONALES'

# %%
df_compras_DIC=pd.concat([df_contratistas_DIC,df_gastos_varios_DIC,df_servicios_DIC, df_comunicacion_DIC, 
                         df_repre_DIC,df_personales_DIC])

# %%
df_compras_DIC=df_compras_DIC.rename(columns={'CB': 'CVE BEN', 'FDO - #OP': 'FDO-#OP'})
df_compras_DIC.head(2)
# Out:
#   CVE BEN       BENEFICIARIO           RFC                 FACTURAS  \
# 0  110036  SEMEX,S.A.DE C.V.  SEM680801193        45024-183011-5970
# 1  110036  SEMEX,S.A.DE C.V.  SEM680801193  FACSMX45343-183011-6204
#
#        CONTRATO                                           CONCEPTO TIPO  \
# 0  SDU-019-2022  ESTIMACION 4 PARA EL SUMINISTRO Y APLICACION D...   TR
# 1  SDU-018-2022  SUMINISTRO DE MATERIALES PARA SEÑALAMIENTOS VI...   TR
#
#        FDO-#OP      FECHA     IMPORTE         SHEET
# 0  330000837.0 2022-12-09  5633016.13  CONTRATISTAS
# 1  330000837.0 2022-12-09  6404531.10  CONTRATISTAS

# %%
df_compras=pd.concat([df_compras_ENE, df_compras_FEB, df_compras_MAR,
                           df_compras_ABR,df_compras_MAY,df_compras_JUN,
                           df_compras_JUL,df_compras_AGO,df_compras_SEP,
                           df_compras_OCT,df_compras_NOV,df_compras_DIC])

# %%
df_compras.head()
# Out:
#         CVE BEN                       BENEFICIARIO           RFC  \
# 0        116117   URBANIZACIONES AGV, S.A. DE C.V.  UAG010828F33
# 1  Total 116117                                NaN           NaN
# 2        123046         CONSTRU-SHENSA, SA. DE CV.  CSH860224497
# 3  Total 123046                                NaN           NaN
# 4        123262  CONSTRUCCIONES DYNAMO, SA. DE CV.  CDY980323MA8
#
#         FACTURAS      CONTRATO  \
# 0  2157-185004-6  SIS-005-2022
# 1            NaN           NaN
# 2   556-185004-9  SIS-002-2022
# 3            NaN           NaN
# 4  1103-185004-7  SIS-008-2022
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  RP 30% ANT. SIS-RP-02/21-CP ADEC. EN INTERS.VI...   TR  1021658.0
# 1                                                NaN  NaN        NaN
# 2  RP 30% ANT. SIS-RP-06/21-CP  CONSTRUCCIÓN DE D...   TR  1021659.0
# 3                                                NaN  NaN        NaN
# ...

# %%
df_compras.columns
# Out:
# Index(['CVE BEN', 'BENEFICIARIO', 'RFC', 'FACTURAS', 'CONTRATO', 'CONCEPTO',
#        'TIPO', 'FDO-#OP', 'FECHA', 'IMPORTE', 'SHEET'],
#       dtype='object')

# %%
df_compras_cl=df_compras.dropna(how='any')

# %%
df_compras_cl.head()
# Out:
#   CVE BEN                           BENEFICIARIO           RFC  \
# 0  116117       URBANIZACIONES AGV, S.A. DE C.V.  UAG010828F33
# 2  123046             CONSTRU-SHENSA, SA. DE CV.  CSH860224497
# 4  123262      CONSTRUCCIONES DYNAMO, SA. DE CV.  CDY980323MA8
# 6  123318  STRUCTOR CONSTRUCCIONES, S.A. DE C.V.  SCO010914CD8
# 8  123530    SERVICIOS POLISEMICOS, S.A. DE C.V.  SPO011004F27
#
#           FACTURAS      CONTRATO  \
# 0    2157-185004-6  SIS-005-2022
# 2     556-185004-9  SIS-002-2022
# 4    1103-185004-7  SIS-008-2022
# 6  AA140-185004-11  SIS-003-2022
# 8    421-185004-10  SIS-010-2022
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  RP 30% ANT. SIS-RP-02/21-CP ADEC. EN INTERS.VI...   TR  1021658.0
# 2  RP 30% ANT. SIS-RP-06/21-CP  CONSTRUCCIÓN DE D...   TR  1021659.0
# 4  RP 30% ANT. SIS-RP-03/21-CP ADEC. EN INTERS.VI...   TR  1021665.0
# 6  RP 30% ANT. SIS-RP-08/21-CP ONSTRUCCIÓN DE OFI...   TR  1021660.0
# ...

# %%
df_compras_cl.to_csv('notebook/data/clean_compras.csv', index=None)

# %%
len(df_compras_cl)
# Out:
# 17696

# %%
df_compras_cl.dtypes
# Out:
# CVE BEN                 object
# BENEFICIARIO            object
# RFC                     object
# FACTURAS                object
# CONTRATO                object
# CONCEPTO                object
# TIPO                    object
# FDO-#OP                float64
# FECHA           datetime64[ns]
# IMPORTE                float64
# SHEET                   object
# dtype: object
